# %% [markdown]
# # Report

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.image as mpimg

# %% [markdown]
# *Both test were done first with 50 users and 3 new per second. And then with 100 users and 3 new persecond.*
# *Both were able to handle 50 users effectively.*
#
# *In this first case, stress test was run with one service.*
# *It was able to contain 50 users simultaneously by handling roughly 11 Requests per second.*
# *It crashed when users were pushed to 100.*

# %%
one_serv = mpimg.imread('uploads/1Service.png')
plt.figure(figsize=(50,5))
imgplot = plt.imshow(one_serv)

# %% [markdown]
# *In this second case, stress test was run with three services.*
# *It was able to contain 50 users simultaneously by handling this time double Requests per second (22).*
# *This also crashed when users were pushed to 100.*
#
# *Would be preferred to test this with a NVIDIA GPU With CUDA.*

# %%
three_serv = mpimg.imread('uploads/3Services.png')
plt.figure(figsize=(50,5))
imgplot = plt.imshow(three_serv)
